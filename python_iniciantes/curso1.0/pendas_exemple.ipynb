# %%
#Importando as bibiotecas
import pandas as pd

# %%
dataframe = pd.read_csv("dados.csv")
print(dataframe.head(5))
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# Obtendo o formato dos dados

# %%
for type in dataframe.dtypes:
    column_types.append(type)
print("\nDataframe types:", column_types, "\n")
# Out:
# Dataframe types: [dtype('O'), dtype('O'), dtype('float64'), dtype('O'), dtype('float64'), dtype('O'), dtype('float64'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('float64'), dtype('O'), dtype('float64'), dtype('O'), dtype('float64'), dtype('O'), dtype('float64')]

# %% [markdown]
# Iteracao por tipos

# %%
for type in dataframe.dtypes:
    column_types.append(type)
print("\nDataframe types:", column_types, "\n")

# %% [markdown]
# Iteracão por colunas

# %%
for i, col in enumerate(dataframe.iteritems()):
    column_name = col[0]
print("Column "+str(i+1)+":"+ column_name, end=" ")
# Out:
# Column 9:Salary

# %% [markdown]
# Valores unicos na coluna

# %%
column_unique_values = list(dataframe[column_name].unique().copy())
print("-Unique values:", column_unique_values, end= " ")
# Out:
# -Unique values: [7730337.0, 6796117.0, nan, 1148640.0, 5000000.0, 12000000.0, 1170960.0, 2165160.0, 1824360.0, 3431040.0, 2569260.0, 6912869.0, 3425510.0, 1749840.0, 2616975.0, 845059.0, 1500000.0, 1335480.0, 6300000.0, 1599840.0, 134215.0, 19689000.0, 1140240.0, 947276.0, 981348.0, 11235955.0, 8000000.0, 1635476.0, 30888.0, 22875000.0, 7402812.0, 1572360.0, 12650000.0, 3750000.0, 4131720.0, 2814000.0, 1636842.0, 4000000.0, 167406.0, 1000000.0, 4626960.0, 1074169.0, 6500000.0, 2144772.0, 525093.0, 3457800.0, 4582680.0, 2869440.0, 1524000.0, 13600000.0, 10050000.0, 2500000.0, 7000000.0, 1842000.0, 6268675.0, 650000.0, 3553917.0, 2900000.0, 245177.0, 4660482.0, 1509360.0, 3873398.0, 13800000.0, 11370786.0, 2008748.0, 14260870.0, 11710456.0, 5543725.0, 1131960.0, 1270964.0, 3815000.0, 15501000.0, 289755.0, 1100602.0, 111444.0, 5675000.0, 9650000.0, 18907726.0, 21468695.0, 3376000.0, 947726.0, 7085000.0, 3110796.0, 1159680.0, 3000000.0, 700000.0, 25000000.0, 15592217.0, 1724250.0, 1155600.0, 3132240.0, 5103120.0, 5219169.0, 13500000.0, 2127840.0, 206192.0, 13000000.0, 1160160.0, 3807120.0, 1035000.0, 55722.0, 5500000.0, 2041080.0, 83397.0, 1015421.0, 6060606.0, 1449187.0, 2836186.0, 3398280.0, 5013559.0, 15851950.0, 12403101.0, 7700000.0, 3156600.0, 9500000.0, 2250000.0, 16407500.0, 4