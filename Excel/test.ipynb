# %%
import pandas as pd

# %%
dados = pd.read_excel('Dados_desembarque_2017.xlsx')

# %%
dados.head()
# Out:
#    Unnamed: 0         ILHA              PORTO DATA DE SAIDA DATA DESEMBARQUE  \
# 0           0  São Vicente  Complexo de pesca    2017-01-17       2017-01-18
# 1           1  São Vicente  Complexo de pesca    2017-01-17       2017-01-18
# 2           2  São Vicente  Complexo de pesca    2017-01-18       2017-01-19
# 3           3  São Vicente  Complexo de pesca    2017-01-18       2017-01-19
# 4           4  São Vicente  Complexo de pesca    2017-01-18       2017-01-19
#
#    MÊS  DIA   ANO        ENGENHO    Grupos              PESCADO CAPTURADO  \
# 0    1   18  2017  Rede de Cerco  Tunideos  Judeu ou Cachorrinha ou Melva
# 1    1   18  2017  Rede de Cerco  Tunideos  Judeu ou Cachorrinha ou Melva
# 2    1   19  2017  Rede de Cerco  Tunideos  Judeu ou Cachorrinha ou Melva
# 3    1   19  2017          linha  Tunideos                       Albacora
# 4    1   19  2017          linha  Tunideos                  Serra ou Djeu
#
# ...

# %%
dados.sort_values ("PORTO", ascending=True)
# Out:
#       Unnamed: 0         ILHA          PORTO DATA DE SAIDA DATA DESEMBARQUE  \
# 1584        1584     Santiago  Cais Da Praia    2017-08-27       2017-08-31
# 1335        1335     Santiago  Cais Da Praia    2017-07-13       2017-07-16
# 1334        1334     Santiago  Cais Da Praia    2017-07-13       2017-07-16
# 1333        1333     Santiago  Cais Da Praia    2017-07-13       2017-07-16
# 1332        1332     Santiago  Cais Da Praia    2017-07-06       2017-07-14
# ...          ...          ...            ...           ...              ...
# 3145        3145  São Nicolau    Tarrafal SN           NaT       2017-06-01
# 3144        3144  São Nicolau    Tarrafal SN           NaT       2017-05-01
# 3168        3168  São Nicolau    Tarrafal SN           NaT       2017-08-01
# 3155        3155  São Nicolau    Tarrafal SN           NaT       2017-04-01
# 3169        3169  São Nicolau    Tarrafal SN           NaT       2017-09-01
#
# ...

# %%
dados[dados['ENGENHO']=='linha']
# Out:
#       Unnamed: 0         ILHA              PORTO DATA DE SAIDA  \
# 3              3  São Vicente  Complexo de pesca    2017-01-18
# 4              4  São Vicente  Complexo de pesca    2017-01-18
# 5              5  São Vicente  Complexo de pesca    2017-01-18
# 25            25  São Vicente  Complexo de pesca    2017-02-18
# 26            26  São Vicente  Complexo de pesca    2017-02-18
# ...          ...          ...                ...           ...
# 2584        2584     Santiago      Cais Da Praia    2017-12-15
# 2585        2585     Santiago      Cais Da Praia    2017-12-22
# 2587        2587     Santiago      Cais Da Praia    2017-12-29
# 2592        2592     Santiago      Cais Da Praia    2017-12-22
# 2593        2593     Santiago      Cais Da Praia    2017-12-22
#
#      DATA DESEMBARQUE  MÊS  DIA   ANO ENGENHO              Grupos  \
# 3          2017-01-19    1   19  2017   linha            Tunideos
# 4          2017-01-19    1   19  2017   linha            Tunideos
# ...
